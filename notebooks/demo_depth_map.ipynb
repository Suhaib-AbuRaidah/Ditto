# %%
import os, sys
sys.path.append('../')
os.environ["PYOPENGL_PLATFORM"] = "egl"

import numpy as np
import json
import math

import torch

import open3d as o3d
import json
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib nbagg
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def plot_3d_point_cloud(x,
                        y,
                        z,
                        show=True,
                        show_axis=True,
                        in_u_sphere=False,
                        marker='.',
                        s=8,
                        alpha=.8,
                        figsize=(5, 5),
                        elev=10,
                        azim=240,
                        axis=None,
                        title=None,
                        lim=None,
                        *args,
                        **kwargs):

    if axis is None:
        fig = plt.figure(figsize=figsize)
        ax = fig.add_subplot(111, projection='3d')
    else:
        ax = axis
        fig = axis

    if title is not None:
        plt.title(title)

    sc = ax.scatter(x, y, z, marker=marker, s=s, alpha=alpha, *args, **kwargs)
    ax.view_init(elev=elev, azim=azim)

    if lim:
        ax.set_xlim3d(*lim[0])
        ax.set_ylim3d(*lim[1])
        ax.set_zlim3d(*lim[2])
    elif in_u_sphere:
        ax.set_xlim3d(-0.5, 0.5)
        ax.set_ylim3d(-0.5, 0.5)
        ax.set_zlim3d(-0.5, 0.5)
    else:
        lim = (min(np.min(x), np.min(y),
                   np.min(z)), max(np.max(x), np.max(y), np.max(z)))
        ax.set_xlim(1.3 * lim[0], 1.3 * lim[1])
        ax.set_ylim(1.3 * lim[0], 1.3 * lim[1])
        ax.set_zlim(1.3 * lim[0], 1.3 * lim[1])
        plt.tight_layout()

    if not show_axis:
        plt.axis('off')

    if show:
        plt.show()

    return fig

# %%
def read_depth(depth_path):
    depth_img = np.array(Image.open(depth_path).convert('L'))
    depth_img = depth_img.astype(np.float32) * 0.001
    
    
    rgbd = o3d.geometry.RGBDImage.create_from_color_and_depth(
        o3d.geometry.Image(np.empty_like(depth_img)),
        o3d.geometry.Image(depth_img),
        depth_scale=1.0,
        depth_trunc=0.7,
        convert_rgb_to_intensity=False,
    )
    return rgbd

def sum_downsample_points(point_list, voxel_size=0.01, nb_neighbors=20, std_ratio=2.0):
    points = np.concatenate([np.asarray(x.points) for x in point_list], axis=0)
    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(points)
    pcd = pcd.voxel_down_sample(voxel_size=voxel_size)
    pcd, _ = pcd.remove_statistical_outlier(nb_neighbors=nb_neighbors, std_ratio=std_ratio)
    return pcd

# %%
def normalize(tensor: torch.Tensor, dim: int) -> torch.Tensor:
    return tensor / ((tensor ** 2).sum(dim, keepdim=True).sqrt() + 1.0e-5)

def vector_to_rotation(vector):
    z = np.array(vector)
    z = z / np.linalg.norm(z)
    x = np.array([1, 0, 0])
    x = x - z*(x.dot(z)/z.dot(z))
    x = x / np.linalg.norm(x)
    y = np.cross(z, x)
    return np.c_[x, y, z]

def add_r_joint_to_scene(scene,
                             axis,
                             pivot_point,
                             length,
                             radius=0.01,
                             joint_color=[200, 0, 0, 180],
                             recenter=False):
    if recenter:
        pivot_point = np.cross(axis, np.cross(pivot_point, axis))
    rotation_mat = vector_to_rotation(axis)
    screw_tran = np.eye(4)
    screw_tran[:3, :3] = rotation_mat
    screw_tran[:3, 3] = pivot_point
    
    axis_cylinder = trimesh.creation.cylinder(radius, height=length)
    axis_arrow = trimesh.creation.cone(radius * 2, radius * 4)
    arrow_trans = np.eye(4)
    arrow_trans[2, 3] = length / 2
    axis_arrow.apply_transform(arrow_trans)
    axis_obj = trimesh.Scene((axis_cylinder, axis_arrow))
    screw = as_mesh(axis_obj)
    
    # screw.apply_translation([0, 0, 0.1])
    screw.apply_transform(screw_tran)
    screw.visual.face_colors = np.array(joint_color, dtype=np.uint8)
    scene.add_geometry(screw)
    return screw

# %% [markdown]
# # load data

# %%
# read data
root = '../data/real_laptop1'
num_point_per_depth = 2048

with open(os.path.join(root, 'camera2base.json')) as f:
    transform_dict = json.load(f)

src_img_dir = os.path.join(root, 'imgs_1')
dst_img_dir = os.path.join(root, 'imgs_2')

transforms = transform_dict['camera2base']
intrinsics = o3d.camera.PinholeCameraIntrinsic(
    width=640,
    height=480,
    fx=635.647,
    fy=635.647,
    cx=321.300,
    cy=241.436,
)
# read data
src_data = []
for idx in range(len(transforms)-5):
    rgbd = read_depth(os.path.join(src_img_dir, f'{idx}_depth.png'))
    src_data.append((rgbd, np.array(transforms[idx])))

dst_data = []
for idx in range(len(transforms)-5):
    rgbd = read_depth(os.path.join(dst_img_dir, f'{idx}_depth.png'))
    dst_data.append((rgbd, np.array(transforms[idx])))

# %%
# crop out the object
bbox = o3d.geometry.AxisAlignedBoundingBox(min_bound=(0.3, -0.5, 0.03), max_bound=(0.7, 0.16, 1))

# find bounding box of data
src_pc_list = []
for rgbd, trans in src_data:
    pcd = o3d.geometry.PointCloud.create_from_rgbd_image(rgbd, intrinsics)
    # pcd, tmp = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=0.01)
    pcd.transform(trans)
    #pcd = pcd.crop(bbox)
    pc = np.asarray(pcd.points)
    pc_idx = np.random.randint(0, pc.shape[0], size=(2048, ))
    pc = pc[pc_idx]
    src_pc_list.append(pc)
src_fused_pc = np.concatenate(src_pc_list, axis=0)
center = (np.min(src_fused_pc, 0) + np.max(src_fused_pc, 0)) / 2
scale = (np.max(src_fused_pc, 0) - np.min(src_fused_pc, 0)).max()
scale *= 1.1

# back project and normalize point cloud

src_pcd_list = []
for rgbd, trans in src_data:
    pcd = o3d.geometry.PointCloud.create_from_rgbd_image(rgbd, intrinsics)
    pcd.transform(trans)
    pcd = pcd.crop(bbox)
    center_transform = np.eye(4)
    center_transform[:3, 3] = -center
    pcd.transform(center_transform)
    pcd.scale(1 / scale, np.zeros((3, 1)))
    src_pcd_list.append(pcd)
    
dst_pcd_list = []
for rgbd, trans in dst_data:
    pcd = o3d.geometry.PointCloud.create_from_rgbd_image(rgbd, intrinsics)
    # pcd, tmp = pcd.remove_statistical_outlier(nb_neighbors=20, std_ratio=0.01)
    pcd.transform(trans)
    pcd = pcd.crop(bbox)
    center_transform = np.eye(4)
    center_transform[:3, 3] = -center
    pcd.transform(center_transform)
    pcd.scale(1 / scale, np.zeros((3, 1)))
    dst_pcd_list.append(pcd)
    
src_pcd = sum_downsample_points(src_pcd_list, 0.02, 50, 0.1)
dst_pcd = sum_downsample_points(dst_pcd_list, 0.02, 50, 0.1)

# %%
# visualize crop results
# tune crop box to get better isolated objects
fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, projection='3d')
plot_3d_point_cloud(*np.asarray(src_pcd.points).T,
                    axis=ax,
                    azim=30,
                    elev=30,
                    lim=[(-0.5, 0.5)] * 3)

ax = fig.add_subplot(1, 2, 2, projection='3d')
plot_3d_point_cloud(*np.asarray(dst_pcd.points).T,
                    axis=ax,
                    azim=30,
                    elev=30,
                    lim=[(-0.5, 0.5)] * 3)

plt.show()
# Out:
# <div id='53c38b03-eb16-4014-816d-4e5428df3988'></div>

# %% [markdown]
# # Run model

# %%
import torch
from hydra.experimental import initialize, initialize_config_module, initialize_config_dir, compose
from omegaconf import OmegaConf
import hydra

from src.third_party.ConvONets.conv_onet.generation_two_stage import Generator3D
from src.utils.misc import sample_point_cloud

# %%
with initialize(config_path='../configs/'):
    config = compose(
        config_name='config',
        overrides=[
            'experiment=Ditto_s2m.yaml',
        ], return_hydra_config=True)
config.datamodule.opt.train.data_dir = '../data/'
config.datamodule.opt.val.data_dir = '../data/'
config.datamodule.opt.test.data_dir = '../data/'
# Out:
# /home/suhaib/miniconda3/envs/Ditto/lib/python3.8/site-packages/hydra/experimental/initialize.py:35: UserWarning: hydra.experimental.initialize() is no longer experimental. Use hydra.initialize()
#   warnings.warn(
# /home/suhaib/miniconda3/envs/Ditto/lib/python3.8/site-packages/hydra/experimental/compose.py:16: UserWarning: hydra.experimental.compose() is no longer experimental. Use hydra.compose()
#   warnings.warn(

# %%
model = hydra.utils.instantiate(config.model)
ckpt = torch.load('../data/Ditto_s2m.ckpt')
device = torch.device(0)
model.load_state_dict(ckpt['state_dict'], strict=True)
model = model.eval().to(device)

# %%
print(model.state_dict().keys())
# Out:
# odict_keys(['model.decoder_occ.fc_c.0.weight', 'model.decoder_occ.fc_c.0.bias', 'model.decoder_occ.fc_c.1.weight', 'model.decoder_occ.fc_c.1.bias', 'model.decoder_occ.fc_c.2.weight', 'model.decoder_occ.fc_c.2.bias', 'model.decoder_occ.fc_c.3.weight', 'model.decoder_occ.fc_c.3.bias', 'model.decoder_occ.fc_c.4.weight', 'model.decoder_occ.fc_c.4.bias', 'model.decoder_occ.blocks.0.fc_0.weight', 'model.decoder_occ.blocks.0.fc_0.bias', 'model.decoder_occ.blocks.0.fc_1.weight', 'model.decoder_occ.blocks.0.fc_1.bias', 'model.decoder_occ.blocks.1.fc_0.weight', 'model.decoder_occ.blocks.1.fc_0.bias', 'model.decoder_occ.blocks.1.fc_1.weight', 'model.decoder_occ.blocks.1.fc_1.bias', 'model.decoder_occ.blocks.2.fc_0.weight', 'model.decoder_occ.blocks.2.fc_0.bias', 'model.decoder_occ.blocks.2.fc_1.weight', 'model.decoder_occ.blocks.2.fc_1.bias', 'model.decoder_occ.blocks.3.fc_0.weight', 'model.decoder_occ.blocks.3.fc_0.bias', 'model.decoder_occ.blocks.3.fc_1.weight', 'model.decoder_occ.blocks.3.fc_1.bias', 'model.decoder_occ.blocks.4.fc_0.weight', 'model.decoder_occ.blocks.4.fc_0.bias', 'model.decoder_occ.blocks.4.fc_1.weight', 'model.decoder_occ.blocks.4.fc_1.bias', 'model.decoder_occ.fc_p.weight', 'model.decoder_occ.fc_p.bias', 'model.decoder_occ.fc_out.weight', 'model.decoder_occ.fc_out.bias', 'model.decoder_seg.fc_c.0.weight', 'model.decoder_seg.fc_c.0.bias', 'model.decoder_seg.fc_c.1.weight', 'model.decoder_seg.fc_c.1.bias', 'model.decoder_seg.fc_c.2.weight', 'model.decoder_seg.fc_c.2.bias', 'model.decoder_seg.fc_c.3.weight', 'model.decoder_seg.fc_c.3.bias', 'model.decoder_seg.fc_c.4.weight', 'model.decoder_seg.fc_c.4.bias', 'model.decoder_seg.blocks.0.fc_0.weight', 'model.decoder_seg.blocks.0.fc_0.bias', 'model.decoder_seg.blocks.0.fc_1.weight', 'model.decoder_seg.blocks.0.fc_1.bias', 'model.decoder_seg.blocks.1.fc_0.weight', 'model.decoder_seg.blocks.1.fc_0.bias', 'model.decoder_seg.blocks.1.fc_1.weight', 'model.decoder_seg.blocks.1.fc_1.bias', 'model.decoder_seg.blocks.2.fc_0.weight', 'model.decoder_seg.blocks.2.fc_0.bias', 'model.decoder_seg.blocks.2.fc_1.weight', 'model.decoder_seg.blocks.2.fc_1.bias', 'model.decoder_seg.blocks.3.fc_0.weight', 'model.decoder_seg.blocks.3.fc_0.bias', 'model.decoder_seg.blocks.3.fc_1.weight', 'model.decoder_seg.blocks.3.fc_1.bias', 'model.decoder_seg.blocks.4.fc_0.weight', 'model.decoder_seg.blocks.4.fc_0.bias', 'model.decoder_seg.blocks.4.fc_1.weight', 'model.decoder_seg.blocks.4.fc_1.bias', 'model.decoder_seg.fc_p.weight', 'model.decoder_seg.fc_p.bias', 'model.decoder_seg.fc_out.weight', 'model.decoder_seg.fc_out.bias', 'model.decoder_joint_type.fc_c.0.weight', 'model.decoder_joint_type.fc_c.0.bias', 'model.decoder_joint_type.fc_c.1.weight', 'model.decoder_joint_type.fc_c.1.bias', 'model.decoder_joint_type.fc_c.2.weight', 'model.decoder_joint_type.fc_c.2.bias', 'model.decoder_joint_type.fc_c.3.weight', 'model.decoder_joint_type.fc_c.3.bias', 'model.decoder_joint_type.fc_c.4.weight', 'model.decoder_joint_type.fc_c.4.bias', 'model.decoder_joint_type.blocks.0.fc_0.weight', 'model.decoder_joint_type.blocks.0.fc_0.bias', 'model.decoder_joint_type.blocks.0.fc_1.weight', 'model.decoder_joint_type.blocks.0.fc_1.bias', 'model.decoder_joint_type.blocks.1.fc_0.weight', 'model.decoder_joint_type.blocks.1.fc_0.bias', 'model.decoder_joint_type.blocks.1.fc_1.weight', 'model.decoder_joint_type.blocks.1.fc_1.bias', 'model.decoder_joint_type.blocks.2.fc_0.weight', 'model.decoder_joint_type.blocks.2.fc_0.bias', 'model.decoder_joint_type.blocks.2.fc_1.weight', 'model.decoder_joint_type.blocks.2.fc_1.bias', 'model.decoder_joint_type.blocks.3.fc_0.weight', 'model.decoder_joint_type.blocks.3.fc_0.bias', 'model.decoder_joint_type.blocks.3.fc_1.weight', 'model.decoder_joint_type.blocks.3.fc_1.bias', 'model.decoder_joint_type.blocks.4.fc_0.weight', 'model.decoder_joint_type.blocks.4.fc_0.bias', 'model.decoder_joint_type.blocks.4.fc_1.weight', 'model.decoder_joint_type.blocks.4.fc_1.bias', 'model.decoder_joint_type.fc_p.wei ...

# %%
generator = Generator3D(
    model.model,
    device=device,
    threshold=0.4,
    seg_threshold=0.5,
    input_type='pointcloud',
    refinement_step=0,
    padding=0.1,
    resolution0=32
)

# %%
pc_start = np.asarray(src_pcd.points)
pc_end = np.asarray(dst_pcd.points)

bound_max = np.maximum(pc_start.max(0), pc_end.max(0))
bound_min = np.minimum(pc_start.min(0), pc_end.min(0))
norm_center = (bound_max + bound_min) / 2
norm_scale = (bound_max - bound_min).max() * 1.1
pc_start = (pc_start - norm_center) / norm_scale
pc_end = (pc_end - norm_center) / norm_scale

pc_start, _ = sample_point_cloud(pc_start, 8192)
pc_end, _ = sample_point_cloud(pc_end, 8192)
sample = {
    'pc_start': torch.from_numpy(pc_start).unsqueeze(0).to(device).float(),
    'pc_end': torch.from_numpy(pc_end).unsqueeze(0).to(device).float()
}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 4
#       1 pc_start = np.asarray(src_pcd.points)
#       2 pc_end = np.asarray(dst_pcd.points)
# ----> 4 bound_max = np.maximum(pc_start.max(0), pc_end.max(0))
#       5 bound_min = np.minimum(pc_start.min(0), pc_end.min(0))
#       6 norm_center = (bound_max + bound_min) / 2
#
# File ~/miniconda3/envs/Ditto/lib/python3.8/site-packages/numpy/core/_methods.py:41, in _amax(a, axis, out, keepdims, initial, where)
#      39 def _amax(a, axis=None, out=None, keepdims=False,
#      40           initial=_NoValue, where=True):
# ---> 41     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
mesh_dict, mobile_points_all, c, stats_dict = generator.generate_mesh(sample)
with torch.no_grad():
    joint_type_logits, joint_param_revolute, joint_param_prismatic = model.model.decode_joints(mobile_points_all, c)

# %%
print(f"\n",mesh_dict,"\n\n\n","\n", c,"\n\n\n", stats_dict)
# Out:
#  {0: <trimesh.Trimesh(vertices.shape=(53316, 3), faces.shape=(106636, 3))>, 1: <trimesh.Trimesh(vertices.shape=(17548, 3), faces.shape=(35064, 3))>}
#
#
#
#  {'geo_grid': tensor([[[[[ 1.0127e-01,  2.6775e-01,  3.5389e-01,  ...,  2.7234e-01,
#              2.6662e-01,  2.5322e-01],
#            [ 8.3786e-02,  4.0517e-01,  5.3247e-01,  ...,  3.5402e-01,
#              3.2781e-01,  3.2063e-01],
#            [ 1.4446e-01,  4.2540e-01,  5.7059e-01,  ...,  3.5528e-01,
#              3.1315e-01,  3.2377e-01],
#            ...,
#            [ 5.7936e-02,  3.0350e-01,  3.1842e-01,  ...,  3.6764e-01,
#              3.9140e-01,  4.5197e-01],
#            [ 1.2249e-02,  3.1331e-01,  3.3739e-01,  ...,  3.5946e-01,
#              3.8097e-01,  4.9879e-01],
#            [-1.1541e-01,  1.0292e-01,  7.7342e-02,  ...,  1.1911e-01,
#              1.2805e-01,  2.9462e-01]],
#
#           [[ 1.1594e-01,  3.2288e-01,  4.4347e-01,  ...,  3.2228e-01,
#              3.1916e-01,  2.7517e-01],
#            [ 8.8916e-02,  5.4752e-01,  7.3169e-01,  ...,  4.0786e-01,
#              3.6410e-01,  3.3020e-01],
#            [ 1.7250e-01,  5.7017e-01,  7.2334e-01,  ...,  3.8767e-01,
#              3.3255e-01,  3.0864e-01],
#           [-0.0392, -0.0428, -0.0578,  ..., -0.0010, -0.1062, -0.1148],
#           [-0.0314, -0.0368, -0.0633,  ..., -0.0032, -0.0473, -0.0721],
#           ...,
#           [-0.1492, -0.4037, -0.5063,  ...,  0.1348,  0.0170, -0.2168],
#           [-0.1190, -0.3148, -0.4147,  ...,  0.0382, -0.0095, -0.1992],
#           [-0.1112, -0.2918, -0.3117,  ...,  0.0127, -0.0437, -0.0835]],
#
#          [[-0.0259, -0.0236, -0.0906,  ...,  0.3181,  0.2335,  0.1417],
#           [-0.0375, -0.0280, -0.0306,  ...,  0.4768,  0.3732,  0.2276],
#           [-0.0663, -0.0030, -0.1073,  ...,  0.6038,  0.4432,  0.3754],
#           ...,
#           [-0.1356, -0.0526, -0.1727,  ...,  0.6167,  0.5883,  0.5720],
#           [-0.0501, -0.0736, -0.1372,  ...,  0.3847,  0.4692,  0.3574],
#           [-0.0869, -0.0724, -0.1236,  ...,  0.1935,  0.1750,  0.2540]],
#
#          [[ 0.1347,  0.1305,  0.1795,  ...,  0.3520,  0.2513,  0.2232],
#           [ 0.0642,  0.2426,  0.2094,  ...,  0.4228,  0.4435,  0.3165],
#           [ 0.1122,  0.1835,  0.2493,  ...,  0.4585,  0.4732,  0.3286],
#           ...,
#           [-0.0219, -0.0104, -0.2303,  ...,  0.2047,  0.4037,  0.3928],
#           [ 0.0828, -0.0779, -0.1880,  ...,  0.1311,  0.3765,  0.2315],
#           [ 0.0162, -0.0259, -0.1211,  ...,  0.1743,  0.2660,  0.1998]],
#
#          ...,
#
#          [[ 0.0110, -0.0212, -0.0138,  ...,  0.0032, -0.0285, -0.0036],
#           [-0.0977, -0.0013, -0.1001,  ..., -0.0762,  0.0014,  0.1157],
#           [-0.0541, -0.0622, -0.0868,  ..., -0.0961, -0.0632,  0.0674],
#           ...,
#           [ 0.0214,  0.3122,  0.3949,  ..., -0.0852,  0.0041, -0.0054],
#           [ 0.0381,  0.1722,  0.1968,  ..., -0.1938, -0.0622, -0.1223],
#           [ 0.0104,  0.1258,  0.2499,  ..., -0.1184,  0.0289, -0.0280]],
#
#          [[-0.0060, -0.0103, -0.0735,  ...,  0.1744,  0.1460,  0.0304],
#           [ 0.0208,  0.0780,  0.0449,  ...,  0.3500,  0.3306,  0.1235],
#           [ 0.0449,  0.1633,  0.0119,  ...,  0.5262,  0.3924,  0.2786],
#           ...,
#           [ 0.0657,  0.0330, -0.0269,  ...,  0.2310,  0.2635,  0.2495],
#           [ 0.1190,  0.1619,  0.0290,  ...,  0.0411,  0.1113,  0.1206],
#           [ 0.1158,  0.1144,  0.0656,  ..., -0.1992, -0.1956,  0.0753]],
#
#          [[-0.0461,  0.0374, -0.0391,  ..., -0.0487, -0.0476, -0.0566],
#           [ 0.0250, -0.0152,  0.0147,  ..., -0.0629, -0.0807, -0.1509],
#           [-0.0359,  0.0480, -0.0289,  ..., -0.0979, -0.1155, -0.1777],
#           ...,
#           [ 0.1086,  0.2109,  0.3875,  ..., -0.3583, -0.4994, -0.6226],
#           [ 0.0306,  0.1522,  0.2762,  ..., -0.3125, -0.2628, -0.5495],
#           [ 0.0258,  0.0599,  0.1164,  ..., -0.0811, -0.2683, -0.3002]]]],
#        device='cuda:0'), 'corr_yz': tensor([[[[-0.0825, -0.0602, -0.1133,  ...,  0.1324,  0.0651, -0.0044],
#           [-0.0983, -0.0652, -0.0400,  ...,  0.1265, -0.0446, -0.1013],
#           [-0.0646,  0.0272, -0.0081,  ...,  0.1650,  0.0864, -0.0355],
#           ...,
#           [-0.0936, -0.2445, -0.3233,  ...,  0.0701,  0.0053, -0.0681],
#           [-0.0674, -0.1898, -0.2265,  ...,  0.0502, -0.0120, -0.0502],
#           [-0.0618, -0.1888, -0.2072,  ...,  0.0450, -0.0155, -0.0160]],
#
#          [[-0.2594, -0.3025, -0.4178,  ...,  0.4275,  0.3121,  0.1864],
#           [-0.3140, -0.4864, -0.3923,  ...,  0.6729,  0.5115,  0.3162],
#           [-0.5333, -0.4955, -0.6720,  ...,  0.8031,  0.6167,  0.4838],
#           ...,
#           [-0.0684,  0.0196, -0.0994,  ...,  0.3222,  0.3092,  0.2310],
#           [ 0.0067, -0.0026, -0.0056,  ...,  0.2426,  0.2547,  0.1747],
#           [-0.0366, -0.0106, -0.0350,  ...,  0.1128,  0.1124,  0.0968]],
#
#          [[ 0.2679,  0.2893,  0.4111,  ...,  0.2895,  0.1919,  0.1678],
#           [ 0.1407,  0.3482,  0.2115,  ...,  0.4322,  0.3886,  0.3011],
#           [ 0.2600,  0.2305,  0.2925,  ...,  0.5096,  0.4755,  0.3245],
#           ...,
#           [ 0.0916,  0.1395, -0.0065,  ...,  0.1317,  0.1805,  0.1901],
#           [ 0.0955,  0.0804,  0.0030,  ...,  0.1077,  0.1718,  0.1250],
#           [ 0.0590,  0.0355,  0.0011,  ...,  0.1244,  0.1310,  0.1053]],
#
#          ...,
#
#          [[ 0.0211, -0.0801, -0.0594,  ..., -0.0397, -0.0835, -0.0742],
#           [-0.2383, -0.1480, -0.5193,  ..., -0.1047, -0.0013,  0.0313],
#           [-0.1644, -0.3497, -0.4302,  ..., -0.1134, -0.1077, -0.0308],
#           ...,
#           [-0.0446,  0.2137,  0.2158,  ..., -0.1627, -0.0796, -0.0429],
#           [-0.0178,  0.0918,  0.0940,  ..., -0.1709, -0.0748, -0.0490],
#           [-0.0457,  0.0679,  0.1326,  ..., -0.1214, -0.0215, -0.0014]],
#
#          [[-0.1319, -0.1371, -0.2108,  ...,  0.2465,  0.1795,  0.0421],
#           [-0.0597, -0.0987, -0.1080,  ...,  0.4410,  0.3677,  0.1282],
#           [-0.0263,  0.1440, -0.1211,  ...,  0.5644,  0.4626,  0.2691],
#           ...,
#           [ 0.0890,  0.1129,  0.0189,  ...,  0.2684,  0.2571,  0.1606],
#           [ 0.1417,  0.1904,  0.1051,  ...,  0.2438,  0.2215,  0.1472],
#           [ 0.1318,  0.1499,  0.1319,  ...,  0.0980,  0.0884,  0.1001]],
#
#          [[-0.3040, -0.2430, -0.3417,  ..., -0.0600, -0.0650, -0.0551],
#           [-0.2841, -0.3639, -0.2698,  ..., -0.0871, -0.1127, -0.1673],
#           [-0.4240, -0.3840, -0.5060,  ..., -0.1090, -0.1388, -0.2372],
#           ...,
#           [ 0.0489,  0.1022,  0.2746,  ..., -0.0010, -0.0849, -0.1744],
#           [ 0.0096,  0.0936,  0.1968,  ..., -0.0042, -0.0854, -0.1641],
#           [ 0.0142,  0.0499,  0.1129,  ...,  0.0444, -0.0553, -0.0873]]]],
#        device='cuda:0'), 'corr_xz': tensor([[[[-0.0198, -0.0250, -0.0593,  ...,  0.1235,  0.0667, -0.0422],
#           [-0.0430, -0.0387, -0.0782,  ...,  0.1594, -0.0073, -0.1243],
#           [-0.0341, -0.0161, -0.0696,  ...,  0.1947,  0.0793, -0.0586],
#           ...,
#           [-0.1017, -0.2670, -0.3440,  ...,  0.1441,  0.0058, -0.1670],
#           [-0.0760, -0.2107, -0.2511,  ...,  0.0370, -0.0162, -0.1582],
#           [-0.0680, -0.2073, -0.2256,  ...,  0.0180, -0.0518, -0.0607]],
#
#          [[-0.0642, -0.0851, -0.1479,  ...,  0.4569,  0.3503,  0.2209],
#           [-0.0790, -0.1045, -0.0927,  ...,  0.7446,  0.5682,  0.3846],
#           [-0.1269, -0.0635, -0.1753,  ...,  0.8628,  0.7019,  0.5461],
#           ...,
#           [-0.0901, -0.0010, -0.1178,  ...,  0.5873,  0.5816,  0.5041],
#           [-0.0080, -0.0233, -0.0193,  ...,  0.3596,  0.4467,  0.3065],
#           [-0.0460, -0.0153, -0.0364,  ...,  0.1832,  0.1939,  0.2180]],
#
#          [[ 0.1704,  0.1870,  0.2637,  ...,  0.3341,  0.2548,  0.2174],
#           [ 0.0816,  0.2531,  0.2415,  ...,  0.4548,  0.4379,  0.3465],
#           [ 0.1453,  0.1765,  0.2711,  ...,  0.4707,  0.4799,  0.3628],
#           ...,
#           [ 0.0958,  0.1411, -0.0222,  ...,  0.1862,  0.3619,  0.3523],
#           [ 0.1027,  0.0685, -0.0152,  ...,  0.1100,  0.3448,  0.2105],
#           [ 0.0612,  0.0261, -0.0140,  ...,  0.1611,  0.2506,  0.1856]],
#
#          ...,
#
#          [[ 0.0102, -0.0242, -0.0284,  ..., -0.0228, -0.0711, -0.0846],
#           [-0.1246, -0.0599, -0.1763,  ..., -0.0997,  0.0268,  0.0093],
#           [-0.0944, -0.1271, -0.1977,  ..., -0.1281, -0.1170, -0.0389],
#           ...,
#           [-0.0432,  0.2531,  0.2469,  ..., -0.0850, -0.0153, -0.0185],
#           [-0.0074,  0.1066,  0.1173,  ..., -0.1723, -0.0626, -0.1087],
#           [-0.0499,  0.0812,  0.1498,  ..., -0.0993,  0.0214, -0.0213]],
#
#          [[-0.0293, -0.0311, -0.0795,  ...,  0.2626,  0.1949,  0.0646],
#           [ 0.0060,  0.0762,  0.0203,  ...,  0.5231,  0.4444,  0.1913],
#           [ 0.0515,  0.1590,  0.0203,  ...,  0.6510,  0.4821,  0.3592],
#           ...,
#           [ 0.0814,  0.0931, -0.0062,  ...,  0.2078,  0.2474,  0.2356],
#           [ 0.1386,  0.1828,  0.0878,  ...,  0.0457,  0.1321,  0.1082],
#           [ 0.1362,  0.1502,  0.1273,  ..., -0.1675, -0.1532,  0.0778]],
#
#          [[-0.0866, -0.0083, -0.0964,  ..., -0.0912, -0.1052, -0.1182],
#           [ 0.0131, -0.0378,  0.0011,  ..., -0.1481, -0.1845, -0.2633],
#           [-0.0666,  0.0510, -0.0564,  ..., -0.1756, -0.1990, -0.3705],
#           ...,
#           [ 0.0501,  0.1180,  0.2985,  ..., -0.2151, -0.3713, -0.5274],
#           [ 0.0118,  0.1072,  0.2215,  ..., -0.1850, -0.2019, -0.4697],
#           [ 0.0140,  0.0636,  0.1340,  ..., -0.0376, -0.2028, -0.2660]]]],
#        device='cuda:0')}
#
#
#  {'time (encode inputs)': 0.23185110092163086, 'time (eval points)': 1.4453246593475342, 'time (marching cubes)': 0.6772925853729248}

# %% [markdown]
# # Visualize results

# %%
import trimesh
from src.utils.joint_estimation import aggregate_dense_prediction_r

from utils3d.mesh.utils import as_mesh
from utils3d.render.pyrender import get_pose, PyRenderer

# %%
renderer = PyRenderer(light_kwargs={'color': np.array([1., 1., 1.]), 'intensity': 9})

# %%
# compute articulation model
mesh_dict[1].visual.face_colors = np.array([84, 220, 83, 255], dtype=np.uint8)
joint_type_prob = joint_type_logits.sigmoid().mean()

if joint_type_prob.item()< 0.5:
    # axis voting
    joint_r_axis = (
        normalize(joint_param_revolute[:, :, :3], -1)[0].cpu().numpy()
    )
    joint_r_t = joint_param_revolute[:, :, 3][0].cpu().numpy()
    joint_r_p2l_vec = (
        normalize(joint_param_revolute[:, :, 4:7], -1)[0].cpu().numpy()
    )
    joint_r_p2l_dist = joint_param_revolute[:, :, 7][0].cpu().numpy()
    p_seg = mobile_points_all[0].cpu().numpy()

    pivot_point = p_seg + joint_r_p2l_vec * joint_r_p2l_dist[:, np.newaxis]
    (
        joint_axis_pred,
        pivot_point_pred,
        config_pred,
    ) = aggregate_dense_prediction_r(
        joint_r_axis, pivot_point, joint_r_t, method="mean"
    )
# prismatic
else:
    # axis voting
    joint_p_axis = (
        normalize(joint_param_prismatic[:, :, :3], -1)[0].cpu().numpy()
    )
    joint_axis_pred = joint_p_axis.mean(0)
    joint_p_t = joint_param_prismatic[:, :, 3][0].cpu().numpy()
    config_pred = joint_p_t.mean()
    
    pivot_point_pred = mesh_dict[1].bounds.mean(0)

# %%
scene = trimesh.Scene()
static_part = mesh_dict[0].copy()
mobile_part = mesh_dict[1].copy()
scene.add_geometry(static_part)
scene.add_geometry(mobile_part)
add_r_joint_to_scene(scene, joint_axis_pred, pivot_point_pred, 1.0, recenter=True)
# Out:
# <trimesh.Trimesh(vertices.shape=(100, 3), faces.shape=(192, 3))>

# %%
# render result mesh
camera_pose = get_pose(1.5, ax=np.pi / 3, ay=0, az=np.pi/2)
light_pose = get_pose(1.5, ax=np.pi / 3, ay=0, az=np.pi/2)
rgb, depth = renderer.render_mesh(scene, camera_pose, light_pose)

# %%
Image.fromarray(rgb).show()
